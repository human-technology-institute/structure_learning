# %% [markdown]
# ### import libraries

# %%
import sys
sys.path.append('../src')

# %%
import numpy as np
from structure_learning.samplers import PartitionMCMC
from structure_learning.data import SyntheticDataset
from structure_learning.distributions import OPAD, Distribution
from structure_learning.data_structures import DAG, Graph
from structure_learning.scores import BGeScore
from structure_learning.evaluation.metrics import KLD, JSD, MAE, MSE, SHD

# %% [markdown]
# ### dataset

# %%
np.random.seed(1000)

num_nodes = 5
node_labels = [chr(ord('a') + i) for i in range(num_nodes)]
num_obs = 10000
degree = 2
synthetic_data = SyntheticDataset(num_nodes=num_nodes, num_obs=num_obs, node_labels=node_labels, degree=degree)
# Out:
# 00000 00000 00000 11101 00100

# %% [markdown]
# ### ground truth

# %%
# visualise ground truth DAG
synthetic_data.graph.plot()
# Out:
# <AGraph <Swig Object of type 'Agraph_t *' at 0x114483de0>>

# %% [markdown]
# ### partition MCMC (w/ OPAD-weighted results)

# %%
# setup mcmc
M = PartitionMCMC(max_iter=100000, data=synthetic_data.data, score_object='bge', searchspace="FULL", result_type='opad+', graph_type='cpdag', plus1=False)

# %%
# run experiment
mcmc_results, acceptance = M.run()
print('Acceptance_ratio:', acceptance)
# Out:
# Adding rejected particles
# Acceptance_ratio: 0.1092

# %%
from matplotlib import pyplot as plt

key = synthetic_data.graph.to_cpdag().to_key()
plt.rcParams['figure.figsize'] = 12,8
bars, keys, counts = mcmc_results.plot(sort=True, normalise=True, limit=20)
bars.containers[0][np.where(np.array(keys)==key)[0][0]].set_color('red')
# Out:
# /Users/165421/Documents/code/structure_learning/examples/../src/structure_learning/distributions/distribution.py:168: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(particles[-limit:], rotation=90)

# %% [markdown]
# ### compute true distribution

# %%
true_dist = Distribution.compute_distribution(synthetic_data.data, score=BGeScore, graph_type='cpdag')
bars2, keys, counts = true_dist.plot(prop='p', sort=True, limit=20)
bars2.containers[0][np.where(np.array(keys)==key)[0][0]].set_color('red')
# Out:
# /Users/165421/Documents/code/structure_learning/examples/../src/structure_learning/distributions/distribution.py:168: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(particles[-limit:], rotation=90)

# %% [markdown]
# ### plot top graph

# %%
Graph.from_key(mcmc_results.top(n=1).item(), nodes=node_labels).plot()
# Out:
# <AGraph <Swig Object of type 'Agraph_t *' at 0x365b73d20>>

# %% [markdown]
# ### KLD

# %%
kld = KLD()
kld_mcmc = kld.compute(mcmc_results, true_dist)

print(kld_mcmc)
# Out:
# 4.607993827135583

# %% [markdown]
# ### JSD

# %%
jsd = JSD()
jsd_mcmc = jsd.compute(mcmc_results, true_dist)

print(jsd_mcmc)
# Out:
# 0.09523931720744769

# %% [markdown]
# ## MSE

# %%
mse = MSE()
mse_mcmc = mse.compute(mcmc_results, true_dist)

print(mse_mcmc)
# Out:
# 6.878907339235979e-06

# %% [markdown]
# ### MAE

# %%
mae = MAE()
mae_mcmc = mae.compute(mcmc_results, true_dist)

print(mae_mcmc)
# Out:
# 5.283358838568947e-05

# %% [markdown]
# ### SHD

# %%
shd = SHD()
shd_mcmc = shd.compute(mcmc_results, synthetic_data.graph)

print(shd_mcmc)
